# %% [markdown]
# <a href="https://colab.research.google.com/github/CommunityRADvocate/ida-colab-test/blob/main/Week_11_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Data

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# There are many different file types your data may come in, and many ways to store and import that data.
#
# The most common format is Comma Separated Values (csv), and `pd.read_csv()` will be your go-to method for importing those.
#
# Some other file types you may encounter include:
# * JSON
# * Excel
# * Text
#
# You can find how to import any applicable file type by typing "pandas import [file type]" in your favorite search engine.

# %% [markdown]
# The site Geeks for Geeks has some good resources that come up in search for how to access datasets in Colab from some common places on the web:
# * Kaggle -  [How to Import Kaggle Datasets Directly into Google Colab](https://www.geeksforgeeks.org/how-to-import-kaggle-datasets-directly-into-google-colab/)
# * Google Drive - [How to Load a Dataset From Google Drive to Colab](https://www.geeksforgeeks.org/how-to-load-a-dataset-from-the-google-drive-to-google-colab/)

# %% [markdown]
# I've uploaded the Music & Mental Health Survey Results to a public [GitHub](https://github.com/CommunityRADvocate/ida2404-capstone/tree/main) repository, which is my preferred method when using Colab to analyze a public dataset.

# %%
# assign raw data link to variable
url = 'https://raw.githubusercontent.com/CommunityRADvocate/ida2404-capstone/main/mxmh_survey_results.csv'
# use variable name as argument
df = pd.read_csv(url)

# %% [markdown]
# ## Exploration Methods

# %%
# see the first few rows of your dataframe
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0           NaN
# 1                       Rarely     7.0        2.0      2.0  1.0           NaN
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
# 2  I understand.
# 3  I understand.
# 4  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# By default this shows the first 5 rows, but you can add a parameter with the number of rows you'd like to view

# %%
df.tail()
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 731           Yes             Yes       No       Rock         Yes
# 732           Yes             Yes       No        Pop         Yes
# 733           Yes              No      Yes        Rap         Yes
# 734           Yes             Yes       No  Classical          No
# 735           Yes              No       No    Hip hop         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 731               Yes  ...            Never           Rarely  Very frequently
# 732               Yes  ...            Never            Never        Sometimes
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 731                        Never     7.0        6.0      0.0  9.0
# 732                    Sometimes     3.0        2.0      2.0  5.0
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
#
#     Music effects    Permissions
# 731       Improve  I understand.
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
#
# [5 rows x 33 columns]

# %%
# view key pieces of information about your dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
#  12  Frequency [Country]           736 non-null    object
#  13  Frequency [EDM]               736 non-null    object
#  14  Frequency [Folk]              736 non-null    object
#  15  Frequency [Gospel]            736 non-null    object
#  16  Frequency [Hip hop]           736 non-null    object
#  17  Frequency [Jazz]              736 non-null    object
#  18  Frequency [K pop]             736 non-null    object
#  19  Frequency [Latin]             736 non-null    object
#  20  Frequency [Lofi]              736 non-null    object
#  21  Frequency [Metal]             736 non-null    object
#  22  Frequency [Pop]               736 non-null    object
#  23  Frequency [R&B]               736 non-null    object
#  24  Frequency [Rap]               736 non-null    object
#  25  Frequency [Rock]              736 non-null    object
#  26  Frequency [Video game music]  736 non-null    object
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    object
#  32  Permissions                   736 non-null    object
# dtypes: float64(7), object(26)
# memory usage: 189.9+ KB

# %%
# statistical insights into numeric data
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Hours per day'].plot(kind='hist', bins=20, title='Hours per day')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['BPM'].plot(kind='hist', bins=20, title='BPM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Anxiety'].plot(kind='hist', bins=20, title='Anxiety')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Age', y='Hours per day', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Hours per day', y='BPM', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='BPM', y='Anxiety', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Anxiety', y='Depression', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Hours per day'].plot(kind='line', figsize=(8, 4), title='Hours per day')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['BPM'].plot(kind='line', figsize=(8, 4), title='BPM')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Anxiety'].plot(kind='line', figsize=(8, 4), title='Anxiety')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Age', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='Hours per day', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='BPM', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='Anxiety', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### Sorting
#
# [Sort values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html)

# %%
# check documentation for parameters
df.sort_values('Age')
# sort descending
df.sort_values('Age', ascending=False)
# permanently change the sort order
df.sort_values('Age', ascending=False, inplace=True)
# revert back to original sort
df.sort_index(inplace=True)

# %%
df
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# 0             Yes             Yes      Yes             Latin         Yes
# 1             Yes              No       No              Rock         Yes
# 2              No              No       No  Video game music          No
# 3             Yes              No      Yes              Jazz         Yes
# 4             Yes              No       No               R&B         Yes
# ..            ...             ...      ...               ...         ...
# 731           Yes             Yes       No              Rock         Yes
# 732           Yes             Yes       No               Pop         Yes
# 733           Yes              No      Yes               Rap         Yes
# 734           Yes             Yes       No         Classical          No
# 735           Yes              No       No           Hip hop         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0                 Yes  ...        Sometimes  Very frequently            Never
# 1                  No  ...        Sometimes           Rarely  Very frequently
# 2                 Yes  ...            Never           Rarely           Rarely
# 3                 Yes  ...        Sometimes            Never            Never
# 4                  No  ...  Very frequently  Very frequently            Never
# ..                ...  ...              ...              ...              ...
# 731               Yes  ...            Never           Rarely  Very frequently
# 732               Yes  ...            Never            Never        Sometimes
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0                      Sometimes     3.0        0.0      1.0  0.0
# 1                         Rarely     7.0        2.0      2.0  1.0
# 2                Very frequently     7.0        7.0     10.0  2.0
# 3                          Never     9.0        7.0      3.0  3.0
# 4                         Rarely     7.0        2.0      5.0  9.0
# ..                           ...     ...        ...      ...  ...
# 731                        Never     7.0        6.0      0.0  9.0
# 732                    Sometimes     3.0        2.0      2.0  5.0
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
#
#     Music effects    Permissions
# 0             NaN  I understand.
# 1             NaN  I understand.
# 2       No effect  I understand.
# 3         Improve  I understand.
# 4         Improve  I understand.
# ..            ...            ...
# 731       Improve  I understand.
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
#
# [736 rows x 33 columns]

# %% [markdown]
# ### Selecting Data
#
# A common task in data analysis is selecting specific subsets of our data that meet certain conditions.
#
# You can create a boolean Series based on your condition and use it as an index to retrieve matching rows.
#
# [Indexing and selecting data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %%
# select rows where Spotify is the user's primary streaming service
spotify = df['Primary streaming service'] == 'Spotify'
df[spotify].head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 7  8/27/2022 22:18:59  21.0                   Spotify            1.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 2            No              No       No  Video game music          No
# 4           Yes              No       No               R&B         Yes
# 5           Yes             Yes      Yes              Jazz         Yes
# 7           Yes              No       No             K pop         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 2               Yes  ...            Never           Rarely           Rarely
# 4                No  ...  Very frequently  Very frequently            Never
# 5               Yes  ...  Very frequently  Very frequently  Very frequently
# 7               Yes  ...        Sometimes           Rarely            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0           NaN
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
# 5                        Never     8.0        8.0      7.0  7.0       Improve
# 7                       Rarely     5.0        3.0      5.0  3.0       Improve
#
#      Permissions
# 0  I understand.
# 2  I understand.
# 4  I understand.
# 5  I understand.
# 7  I understand.
#
# [5 rows x 33 columns]

# %%
# a tilde (~) can be prefixed to the boolean series to obtain the inversed index
df[~spotify].head()
# Out:
#              Timestamp   Age          Primary streaming service  \
# 1   8/27/2022 19:57:31  63.0                            Pandora
# 3   8/27/2022 21:40:40  61.0                      YouTube Music
# 6   8/27/2022 22:00:29  18.0                      YouTube Music
# 9   8/27/2022 22:44:03  18.0  I do not use a streaming service.
# 11  8/27/2022 23:00:32  19.0                      YouTube Music
#
#     Hours per day While working Instrumentalist Composer         Fav genre  \
# 1             1.5           Yes              No       No              Rock
# 3             2.5           Yes              No      Yes              Jazz
# 6             3.0           Yes             Yes       No  Video game music
# 9             1.0           Yes              No       No               R&B
# 11            8.0           Yes              No       No               EDM
#
#    Exploratory Foreign languages  ...  Frequency [R&B] Frequency [Rap]  \
# 1          Yes                No  ...        Sometimes          Rarely
# 3          Yes               Yes  ...        Sometimes           Never
# 6          Yes               Yes  ...           Rarely           Never
# 9          Yes               Yes  ...        Sometimes          Rarely
# 11         Yes                No  ...           Rarely       Sometimes
#
#    Frequency [Rock] Frequency [Video game music] Anxiety Depression Insomnia  \
# 1   Very frequently                       Rarely     7.0        2.0      2.0
# 3             Never                        Never     9.0        7.0      3.0
# 6             Never                    Sometimes     4.0        8.0      6.0
# 9         Sometimes                    Sometimes     2.0        2.0      5.0
# 11           Rarely                       Rarely     1.0        0.0      0.0
#
#     OCD Music effects    Permissions
# 1   1.0           NaN  I understand.
# 3   3.0       Improve  I understand.
# 6   0.0       Improve  I understand.
# 9   1.0       Improve  I understand.
# 11  1.0       Improve  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# You don't have to store the index in a variable

# %%
df[df['Fav genre'] == 'Jazz'].head()
# Out:
#              Timestamp   Age Primary streaming service  Hours per day  \
# 3   8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 5   8/27/2022 21:56:50  18.0                   Spotify            5.0
# 14  8/27/2022 23:16:06  18.0                   Spotify            4.0
# 75  8/28/2022 14:04:20  16.0                   Spotify            5.0
# 81  8/28/2022 14:14:48  19.0                   Spotify            3.0
#
#    While working Instrumentalist Composer Fav genre Exploratory  \
# 3            Yes              No      Yes      Jazz         Yes
# 5            Yes             Yes      Yes      Jazz         Yes
# 14           Yes             Yes       No      Jazz         Yes
# 75           Yes             Yes      Yes      Jazz         Yes
# 81           Yes              No       No      Jazz         Yes
#
#    Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 3                Yes  ...        Sometimes            Never            Never
# 5                Yes  ...  Very frequently  Very frequently  Very frequently
# 14               Yes  ...            Never            Never        Sometimes
# 75               Yes  ...           Rarely  Very frequently        Sometimes
# 81                No  ...        Sometimes        Sometimes           Rarely
#
#    Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 3                         Never     9.0        7.0      3.0  3.0
# 5                         Never     8.0        8.0      7.0  7.0
# 14                       Rarely     6.0        4.0      7.0  0.0
# 75                        Never     7.0        7.0      8.0  4.0
# 81              Very frequently     3.0        0.0      0.0  0.0
#
#    Music effects    Permissions
# 3        Improve  I understand.
# 5        Improve  I understand.
# 14       Improve  I understand.
# 75       Improve  I understand.
# 81       Improve  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# You can use the boolean Series as an index with the .loc object

# %%
# retrieve a subset of our data showing the age and hours per day columns of users who primarily stream on spotify
df.loc[spotify, ['Age', 'Hours per day', 'Primary streaming service']]
# Out:
#       Age  Hours per day Primary streaming service
# 0    18.0            3.0                   Spotify
# 2    18.0            4.0                   Spotify
# 4    18.0            4.0                   Spotify
# 5    18.0            5.0                   Spotify
# 7    21.0            1.0                   Spotify
# ..    ...            ...                       ...
# 725  13.0            1.0                   Spotify
# 730  21.0            2.0                   Spotify
# 731  17.0            2.0                   Spotify
# 732  18.0            1.0                   Spotify
# 734  19.0            5.0                   Spotify
#
# [458 rows x 3 columns]

# %% [markdown]
# We can use bitwise operators to compare boolean Series against each other

# %%
# select rows of users who primarily stream spotify and are over the age of 30
df[spotify & (df['Age'] > 30)]
# Out:
#               Timestamp   Age Primary streaming service  Hours per day  \
# 46   8/28/2022 12:15:02  36.0                   Spotify            1.0
# 64   8/28/2022 13:42:20  32.0                   Spotify            5.0
# 65   8/28/2022 13:43:06  36.0                   Spotify            6.0
# 71   8/28/2022 14:00:18  31.0                   Spotify            2.0
# 85   8/28/2022 14:26:12  37.0                   Spotify            1.0
# ..                  ...   ...                       ...            ...
# 650   9/13/2022 7:12:07  37.0                   Spotify            2.0
# 662   9/14/2022 0:58:57  32.0                   Spotify            1.0
# 695  9/28/2022 17:25:48  89.0                   Spotify           24.0
# 702  10/3/2022 10:53:28  37.0                   Spotify            2.0
# 709   10/4/2022 0:48:34  35.0                   Spotify            4.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 46             No             Yes      Yes  Classical          No
# 64            Yes              No       No       Rock          No
# 65            Yes              No       No      Metal         Yes
# 71            Yes              No       No       Rock         Yes
# 85            Yes              No       No       Rock          No
# ..            ...             ...      ...        ...         ...
# 650           Yes              No       No       Rock         Yes
# 662           Yes              No       No      Metal         Yes
# 695           Yes             Yes      Yes        Rap          No
# 702           Yes              No       No       Folk         Yes
# 709           Yes             Yes      Yes    Hip hop         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 46                 No  ...            Never            Never        Sometimes
# 64                Yes  ...  Very frequently           Rarely  Very frequently
# 65                Yes  ...            Never            Never        Sometimes
# 71                Yes  ...            Never            Never  Very frequently
# 85                 No  ...           Rarely           Rarely  Very frequently
# ..                ...  ...              ...              ...              ...
# 650                No  ...           Rarely           Rarely        Sometimes
# 662               Yes  ...           Rarely        Sometimes  Very frequently
# 695                No  ...        Sometimes  Very frequently           Rarely
# 702                No  ...           Rarely           Rarely        Sometimes
# 709                No  ...  Very frequently  Very frequently        Sometimes
#
#     Frequency [Video game music] Anxiety Depression Insomnia   OCD  \
# 46                         Never     8.0        9.0      3.0   0.0
# 64                         Never    10.0       10.0      3.0   1.0
# 65               Very frequently     5.0        4.0     10.0   2.0
# 71                         Never    10.0        2.0      0.0   5.0
# 85                         Never     9.0       10.0      6.0  10.0
# ..                           ...     ...        ...      ...   ...
# 650                        Never     8.0       10.0     10.0   2.0
# 662                       Rarely     6.0        8.0      7.0   0.0
# 695                        Never     0.0        0.0      0.0   0.0
# 702                    Sometimes     6.0        4.0      5.0   0.0
# 709              Very frequently     7.0        8.0      6.0   5.0
#
#     Music effects    Permissions
# 46      No effect  I understand.
# 64         Worsen  I understand.
# 65        Improve  I understand.
# 71      No effect  I understand.
# 85      No effect  I understand.
# ..            ...            ...
# 650        Worsen  I understand.
# 662       Improve  I understand.
# 695     No effect  I understand.
# 702       Improve  I understand.
# 709       Improve  I understand.
#
# [62 rows x 33 columns]

# %% [markdown]
# ### Manipulation
#
# You'll often need to add, remove, or otherwise modify data

# %% [markdown]
# #### Assigning values
#
# Our 'Music effects' column had some empty values. In Sheets we replaced those with 'No effect' rather than delete those rows. We can do the same with Pandas.

# %%
df.info()

# %%
# identify the rows with missing values in column
df[df['Music effects'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, Exploratory, Foreign languages, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects, Permissions]
# Index: []
#
# [0 rows x 33 columns]

# %%
# cannot update with chaining
df[df['Music effects'].isnull()]['Music effects'] = 'No effect'
# Out:
# <ipython-input-24-17aeba319ee7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Music effects'].isnull()]['Music effects'] = 'No effect'

# %%
# replace null values in column using .loc
df.loc[df['Music effects'].isnull(), 'Music effects'] = 'No effect'

# %%
# check that the values have been updated

# %% [markdown]
# #### Adding rows

# %%
new_response = {
    "Timestamp": "5/27/2024 17:39:08",
    "Age": 32,
    "Primary streaming service": "Apple Music",
    "Hours per day": 3,
    "While working": "Yes",
    "Instrumentalist": "Yes",
    "Composer": "No",
    "Fav genre": "Classical",
    "Exploratory": "Yes",
    "Foreign languages": "Yes",
    "BPM": 100,
    "Frequency [Classical]": "Very frequently",
    "Frequency [Country]": "Rarely",
    "Frequency [EDM]": "Rarely",
    "Frequency [Folk]": "Sometimes",
    "Frequency [Gospel]": "Never",
    "Frequency [Hip hop]": "Sometimes",
    "Frequency [Jazz]": "Sometimes",
    "Frequency [K pop]": "Rarely",
    "Frequency [Latin]": "Sometimes",
    "Frequency [Lofi]": "Very frequently",
    "Frequency [Metal]": "Rarely",
    "Frequency [Pop]": "Sometimes",
    "Frequency [R&B]": "Sometimes",
    "Frequency [Rap]": "Sometimes",
    "Frequency [Rock]": "Sometimes",
    "Frequency [Video game music]": "Very frequently",
    "Anxiety": 5,
    "Depression": 6,
    "Insomnia": 1,
    "OCD": 6,
    "Music effects": "Improve",
    "Permissions": "I understand."
  }

# %%
df.append(new_response, ignore_index=True)

# %% [markdown]
# *As of Pandas 2.0, `.append()` is no longer supported.*
#
# You can instead use a combination of `.loc` and `len()` to add a single series to the end of your dataframe.

# %%
df.loc[len(df.index)] = pd.Series(new_response)

# %%
# view the end of our dataframe with .tail()
df.tail()
# Out:
#               Timestamp   Age Primary streaming service  Hours per day  \
# 732  11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733  11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734  11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735   11/9/2022 1:55:20  29.0             YouTube Music            2.0
# 736  5/27/2024 17:39:08  32.0               Apple Music            3.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 732           Yes             Yes       No        Pop         Yes
# 733           Yes              No      Yes        Rap         Yes
# 734           Yes             Yes       No  Classical          No
# 735           Yes              No       No    Hip hop         Yes
# 736           Yes             Yes       No  Classical         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 732               Yes  ...            Never            Never        Sometimes
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
# 736               Yes  ...        Sometimes        Sometimes        Sometimes
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 732                    Sometimes     3.0        2.0      2.0  5.0
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
# 736              Very frequently     5.0        6.0      1.0  6.0
#
#     Music effects    Permissions
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
# 736       Improve  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# To add multiple rows to your dataframe, consider using `pd.concat()`

# %%
# creating the DataFrames
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
					'B': ['B0', 'B1', 'B2', 'B3']})

df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
					'B': ['B4', 'B5', 'B6', 'B7']})

df2
# Out:
#     A   B
# 0  A4  B4
# 1  A5  B5
# 2  A6  B6
# 3  A7  B7

# %%
# concatenate the dataframes
df3 = pd.concat([df1, df2], ignore_index = True)
df3
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5
# 6  A6  B6
# 7  A7  B7

# %% [markdown]
# ##### Setting with Enlargement
#
# Assigning to a non-existent index key will automatically enlarge the dataframe and the row will be added.
#
# For autogenerated indexes, a popular workaround is figuring out the last used index and then incrementing it

# %%
new_response = {
    "Timestamp": "5/27/2024 18:39:08",
    "Age": 50,
    "Primary streaming service": "Spotify",
    "Hours per day": 10,
    "While working": "Yes",
    "Instrumentalist": "No",
    "Composer": "No",
    "Fav genre": "Rock",
    "Exploratory": "Yes",
    "Foreign languages": "Yes",
    "BPM": 122,
    "Frequency [Classical]": "Very frequently",
    "Frequency [Country]": "Rarely",
    "Frequency [EDM]": "Rarely",
    "Frequency [Folk]": "Sometimes",
    "Frequency [Gospel]": "Never",
    "Frequency [Hip hop]": "Sometimes",
    "Frequency [Jazz]": "Sometimes",
    "Frequency [K pop]": "Rarely",
    "Frequency [Latin]": "Sometimes",
    "Frequency [Lofi]": "Very frequently",
    "Frequency [Metal]": "Rarely",
    "Frequency [Pop]": "Sometimes",
    "Frequency [R&B]": "Sometimes",
    "Frequency [Rap]": "Sometimes",
    "Frequency [Rock]": "Sometimes",
    "Frequency [Video game music]": "Very frequently",
    "Anxiety": 0,
    "Depression": 2,
    "Insomnia": 3,
    "OCD": 0,
    "Music effects": "No effect",
    "Permissions": "I understand."
  }

next_key = df.index.max() + 1
df.loc[next_key] = new_response

# check that it was added
df.tail()
# Out:
#               Timestamp   Age Primary streaming service  Hours per day  \
# 733  11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734  11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735   11/9/2022 1:55:20  29.0             YouTube Music            2.0
# 736  5/27/2024 17:39:08  32.0               Apple Music            3.0
# 737  5/27/2024 18:39:08  50.0                   Spotify           10.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 733           Yes              No      Yes        Rap         Yes
# 734           Yes             Yes       No  Classical          No
# 735           Yes              No       No    Hip hop         Yes
# 736           Yes             Yes       No  Classical         Yes
# 737           Yes              No       No       Rock         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
# 736               Yes  ...        Sometimes        Sometimes        Sometimes
# 737               Yes  ...        Sometimes        Sometimes        Sometimes
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
# 736              Very frequently     5.0        6.0      1.0  6.0
# 737              Very frequently     0.0        2.0      3.0  0.0
#
#     Music effects    Permissions
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
# 736       Improve  I understand.
# 737     No effect  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Adding Columns
#
# Can use some of the same principles as adding rows
#
# Missing values will be set to `np.nan`
#
# We can add a calculated column with our various mental health scores using Enlargement

# %%
mental_scores = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
# referencing a column that doesn't exist will add it to our dataframe
df['Mental health score'] = df[mental_scores].sum(axis=1)

# %%
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [Rock] Frequency [Video game music]  \
# 0               Yes  ...             Never                    Sometimes
# 1                No  ...   Very frequently                       Rarely
# 2               Yes  ...            Rarely              Very frequently
# 3               Yes  ...             Never                        Never
# 4                No  ...             Never                       Rarely
#
#   Anxiety Depression Insomnia  OCD Music effects    Permissions  \
# 0     3.0        0.0      1.0  0.0     No effect  I understand.
# 1     7.0        2.0      2.0  1.0     No effect  I understand.
# 2     7.0        7.0     10.0  2.0     No effect  I understand.
# 3     9.0        7.0      3.0  3.0       Improve  I understand.
# 4     7.0        2.0      5.0  9.0       Improve  I understand.
#
#   Mental health score Mental health average
# 0                 4.0                  1.00
# 1                12.0                  3.00
# 2                26.0                  6.50
# 3                22.0                  5.50
# 4                23.0                  5.75
#
# [5 rows x 35 columns]

# %%
# add calculated columns for average mental health scores
df['Mental health average'] = df[mental_scores].mean(axis=1)

# %%
df.describe()

# %% [markdown]
# ##### Renaming columns
#
# Sometimes it makes sense to rename columns, whether to make them more human-readable or to make them easier to reference.
#
# You can do this a few different ways using the `DataFrame.rename()` method
#
# [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html)

# %%
df3
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5
# 6  A6  B6
# 7  A7  B7

# %%
col_names = {'A': 'Primary', 'B': 'Secondary'}
df3.rename(columns = col_names)
# Out:
#   Primary Secondary
# 0      A0        B0
# 1      A1        B1
# 2      A2        B2
# 3      A3        B3
# 4      A4        B4
# 5      A5        B5
# 6      A6        B6
# 7      A7        B7

# %%
df3.rename(str.lower, axis = 'columns', inplace=True)
df3
# Out:
#     a   b
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5
# 6  A6  B6
# 7  A7  B7

# %% [markdown]
# ##### Deleting columns
#
# You can either use slicing to exclude specific columns, or remove them using `.drop()`

# %%
df.drop(columns=['Mental health score', 'Mental health average'], inplace=True)
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0     No effect
# 1                       Rarely     7.0        2.0      2.0  1.0     No effect
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
# 2  I understand.
# 3  I understand.
# 4  I understand.
#
# [5 rows x 33 columns]

# %% [markdown]
# This method can also be used to remove rows by index

# %%
# view the end of our dataframe to get last index numbers
df.tail()
# Out:
#               Timestamp   Age Primary streaming service  Hours per day  \
# 733  11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734  11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735   11/9/2022 1:55:20  29.0             YouTube Music            2.0
# 736  5/27/2024 17:39:08  32.0               Apple Music            3.0
# 737  5/27/2024 18:39:08  50.0                   Spotify           10.0
#
#     While working Instrumentalist Composer  Fav genre Exploratory  \
# 733           Yes              No      Yes        Rap         Yes
# 734           Yes             Yes       No  Classical          No
# 735           Yes              No       No    Hip hop         Yes
# 736           Yes             Yes       No  Classical         Yes
# 737           Yes              No       No       Rock         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
# 736               Yes  ...        Sometimes        Sometimes        Sometimes
# 737               Yes  ...        Sometimes        Sometimes        Sometimes
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
# 736              Very frequently     5.0        6.0      1.0  6.0
# 737              Very frequently     0.0        2.0      3.0  0.0
#
#     Music effects    Permissions
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
# 736       Improve  I understand.
# 737     No effect  I understand.
#
# [5 rows x 33 columns]

# %%
df.drop([736, 737])
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# 0             Yes             Yes      Yes             Latin         Yes
# 1             Yes              No       No              Rock         Yes
# 2              No              No       No  Video game music          No
# 3             Yes              No      Yes              Jazz         Yes
# 4             Yes              No       No               R&B         Yes
# ..            ...             ...      ...               ...         ...
# 731           Yes             Yes       No              Rock         Yes
# 732           Yes             Yes       No               Pop         Yes
# 733           Yes              No      Yes               Rap         Yes
# 734           Yes             Yes       No         Classical          No
# 735           Yes              No       No           Hip hop         Yes
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0                 Yes  ...        Sometimes  Very frequently            Never
# 1                  No  ...        Sometimes           Rarely  Very frequently
# 2                 Yes  ...            Never           Rarely           Rarely
# 3                 Yes  ...        Sometimes            Never            Never
# 4                  No  ...  Very frequently  Very frequently            Never
# ..                ...  ...              ...              ...              ...
# 731               Yes  ...            Never           Rarely  Very frequently
# 732               Yes  ...            Never            Never        Sometimes
# 733                No  ...        Sometimes        Sometimes           Rarely
# 734                No  ...            Never            Never            Never
# 735               Yes  ...  Very frequently  Very frequently  Very frequently
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0                      Sometimes     3.0        0.0      1.0  0.0
# 1                         Rarely     7.0        2.0      2.0  1.0
# 2                Very frequently     7.0        7.0     10.0  2.0
# 3                          Never     9.0        7.0      3.0  3.0
# 4                         Rarely     7.0        2.0      5.0  9.0
# ..                           ...     ...        ...      ...  ...
# 731                        Never     7.0        6.0      0.0  9.0
# 732                    Sometimes     3.0        2.0      2.0  5.0
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
#
#     Music effects    Permissions
# 0       No effect  I understand.
# 1       No effect  I understand.
# 2       No effect  I understand.
# 3         Improve  I understand.
# 4         Improve  I understand.
# ..            ...            ...
# 731       Improve  I understand.
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
#
# [736 rows x 33 columns]

# %% [markdown]
# ### Combining Data Frames
#
# [Documentation for .merge()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)

# %%
url = 'https://raw.githubusercontent.com/CommunityRADvocate/ida-colabs/main/data/transactions.csv'
transactions = pd.read_csv(url, index_col=0)
url = 'https://raw.githubusercontent.com/CommunityRADvocate/ida-colabs/main/data/requests.csv'
requests = pd.read_csv(url, index_col=0)
transactions.shape, requests.shape
# Out:
# ((998, 4), (313, 4))

# %%
transactions.head()
# Out:
#        sender      receiver  amount   sent_date
# 0       stein        smoyer   49.03  2018-01-24
# 1  holden4580  joshua.henry   34.64  2018-02-06
# 2  rose.eaton   emily.lewis   62.67  2018-02-15
# 3      lmoore        kallen    1.94  2018-03-05
# 4   scott3928        lmoore   27.82  2018-03-10

# %%
requests.head()
# Out:
#            from_user        to_user  amount request_date
# 0          chad.chen      paula7980   78.61   2018-02-12
# 1             kallen         lmoore    1.94   2018-02-23
# 2  gregory.blackwell  rodriguez5768   30.57   2018-03-04
# 3    kristina.miller     john.hardy   77.05   2018-03-12
# 4          lacey8987        mcguire   54.09   2018-03-13

# %%
# Since we are calling merge on the `requests` DataFrame it is considered the left side
successful_requests = requests.merge(
    # And transactions is the right side
    transactions,
    # So now we line up columns that will make the join make sense.
    left_on=['from_user', 'to_user', 'amount'],
    right_on=['receiver', 'sender', 'amount']
)
# Let's take a look and see how we did
successful_requests.head()
# Out:
#            from_user        to_user  amount request_date         sender  \
# 0          chad.chen      paula7980   78.61   2018-02-12      paula7980
# 1             kallen         lmoore    1.94   2018-02-23         lmoore
# 2  gregory.blackwell  rodriguez5768   30.57   2018-03-04  rodriguez5768
# 3    kristina.miller     john.hardy   77.05   2018-03-12     john.hardy
# 4          lacey8987        mcguire   54.09   2018-03-13        mcguire
#
#             receiver   sent_date
# 0          chad.chen  2018-07-15
# 1             kallen  2018-03-05
# 2  gregory.blackwell  2018-03-17
# 3    kristina.miller  2018-04-25
# 4          lacey8987  2018-06-28

# %% [markdown]
# ### Gather Insights

# %%
successful_requests.dtypes
# Out:
# from_user        object
# to_user          object
# amount          float64
# request_date     object
# sender           object
# receiver         object
# sent_date        object
# dtype: object

# %%
# convert respective columns to datetime format
successful_requests['request_date'] = pd.to_datetime(successful_requests['request_date'])
successful_requests['sent_date'] = pd.to_datetime(successful_requests['sent_date'])
# And now we can see they are converted
successful_requests.dtypes
# Out:
# from_user               object
# to_user                 object
# amount                 float64
# request_date    datetime64[ns]
# sender                  object
# receiver                object
# sent_date       datetime64[ns]
# dtype: object

# %%
# create a new column with elapsed time between requested and sent
successful_requests['time_passed'] = successful_requests.sent_date - successful_requests.request_date

# %%
# see 5 longest request to successful transactions
successful_requests.sort_values(by='time_passed', ascending=False).tail(5)
# Out:
#        from_user    to_user  amount request_date     sender     receiver  \
# 48     austin486     shelly   11.24   2018-05-29     shelly    austin486
# 187   joshua9690  david2796   60.54   2018-09-16  david2796   joshua9690
# 28    hoover4302     dennis   87.77   2018-05-05     dennis   hoover4302
# 189     gstevens  awilliams   52.05   2018-09-16  awilliams     gstevens
# 213  timothy3285   patricia   36.09   2018-09-25   patricia  timothy3285
#
#      sent_date time_passed
# 48  2018-05-29      0 days
# 187 2018-09-16      0 days
# 28  2018-05-05      0 days
# 189 2018-09-16      0 days
# 213 2018-09-25      0 days

# %%
"Wow! ${:,.2f} has passed through the request system in {} transactions!!!".format(
    successful_requests.amount.sum(),
    len(successful_requests),
)
# Out:
# 'Wow! $10,496.47 has passed through the request system in 214 transactions!!!'

# %% [markdown]
# ### Handling Duplicates
#
# [Documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html)

# %%
# Create a boolean Series of records that are duplicated.
#   Note that `keep=False` marks all that are duplicated
dupes = requests[requests.duplicated(('from_user', 'to_user', 'amount'), keep=False)]
# Order by requester and the date of request.
#   Note that `request_date` in this case is a string, but this string date format sorts properly still.
dupes.sort_values(['from_user', 'request_date'])
# Out:
#            from_user        to_user  amount request_date
# 58         austin486         shelly   11.24   2018-05-29
# 59         austin486         shelly   11.24   2018-05-29
# 8           cjimenez    sarah.evans   48.14   2018-03-21
# 26          cjimenez    sarah.evans   48.14   2018-04-27
# 218        clark8139          moore   14.54   2018-08-31
# 240        clark8139          moore   14.54   2018-09-10
# 195        diane4652       dean2365    6.82   2018-08-21
# 224        diane4652       dean2365    6.82   2018-09-05
# 143        donna1922      danderson   79.22   2018-07-23
# 157        donna1922      danderson   79.22   2018-07-31
# 116      edwards8658   johnston2281   47.29   2018-07-10
# 127      edwards8658   johnston2281   47.29   2018-07-16
# 289          heather        smercer   98.13   2018-09-22
# 290          heather        smercer   98.13   2018-09-22
# 32        hoover4302         dennis   87.77   2018-05-04
# 33        hoover4302         dennis   87.77   2018-05-05
# 160         jcoleman        fuentes   40.48   2018-08-03
# 216         jcoleman        fuentes   40.48   2018-08-29
# 82             jones      jones5796   95.88   2018-06-21
# 95             jones      jones5796   95.88   2018-06-27
# 84          kimberly         wbrown    9.02   2018-06-24
# 101         kimberly         wbrown    9.02   2018-06-28
# 60              kirk          jason   36.53   2018-05-30
# 85              kirk          jason   36.53   2018-06-24
# 165     lawrence1685     joshua9690   99.96   2018-08-07
# 168     lawrence1685     joshua9690   99.96   2018-08-08
# 114         lspencer          sarah   44.89   2018-07-09
# 194         lspencer          sarah   44.89   2018-08-21
# 44       matthew7940     sherry6113   58.72   2018-05-13
# 108      matthew7940     sherry6113   58.72   2018-07-04
# 201      michael7792       jennifer   90.56   2018-08-23
# 241      michael7792       jennifer   90.56   2018-09-10
# 75   nicholas.travis          corey   73.25   2018-06-15
# 109  nicholas.travis          corey   73.25   2018-07-04
# 307         patricia     martha6969   87.33   2018-09-25
# 312         patricia     martha6969   87.33   2018-09-25
# 10         paula7980      mackenzie   56.00   2018-03-29
# 15         paula7980      mackenzie   56.00   2018-04-15
# 68         paula7980      mackenzie   56.00   2018-06-02
# 221     phillips5654  miguel.gamble   11.35   2018-09-01
# 260     phillips5654  miguel.gamble   11.35   2018-09-15
# 139       rebecca848          mpaul    1.34   2018-07-21
# 229       rebecca848          mpaul    1.34   2018-09-06
# 115    rodriguez9475     miller8552   25.89   2018-07-09
# 121    rodriguez9475     miller8552   25.89   2018-07-13

# %%
url = 'https://raw.githubusercontent.com/CommunityRADvocate/ida-colabs/main/data/users.csv'
users = pd.read_csv(url, index_col=0)

# %%
# Let's get our records sorted chronologically
successful_requests.sort_values('request_date', inplace=True)

# And then we'll drop dupes keeping only the last one.
#  Note the use of the inplace keyword
successful_requests.drop_duplicates(('from_user', 'to_user', 'amount'), keep='last', inplace=True)

# Statement from previous notebook
"Wow! ${:,.2f} has passed through the request system in {} transactions!!!".format(
    successful_requests.amount.sum(),
    len(successful_requests),
)
# Out:
# 'Wow! $9,316.12 has passed through the request system in 191 transactions!!!'

# %% [markdown]
# #### Locating records not found in another DF using `isin`
#
# [Documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isin.html)

# %%
# Create a boolean array where we check to see if the label (username)
#   is in the `from_user` Series.
made_request_index = users.index.isin(requests.from_user)
# This will get us a list of all users who **have** made a request
users[made_request_index].head()
# Out:
#               first_name last_name                          email  \
# aaron              Aaron     Davis            aaron6348@gmail.com
# acook            Anthony      Cook                 cook@gmail.com
# adam.saunders       Adam  Saunders                 adam@gmail.com
# adrian            Adrian      Fang  adrian.fang@teamtreehouse.com
# adrian.blair      Adrian     Blair           adrian9335@gmail.com
#
#                email_verified signup_date  referral_count  balance
# aaron                    True  2018-08-31               6    18.14
# acook                    True  2018-05-12               2    55.45
# adam.saunders           False  2018-05-29               3    72.12
# adrian                   True  2018-04-28               3    30.01
# adrian.blair             True  2018-06-16               7    25.85

# %%
users[~made_request_index].head()
# Out:
#          first_name last_name                    email  email_verified  \
# alan9443       Alan      Pope         pope@hotmail.com            True
# alvarado     Denise  Alvarado     alvarado@hotmail.com            True
# amiller        Anne    Miller       miller@hotmail.com           False
# andersen       Mark  Andersen  mark.andersen@yahoo.com            True
# andrade     Melissa   Andrade       mandrade@yahoo.com            True
#
#          signup_date  referral_count  balance
# alan9443  2018-04-17               0    56.09
# alvarado  2018-09-07               6    26.72
# amiller   2018-06-02               5    86.28
# andersen  2018-08-21               3    75.69
# andrade   2018-01-06               3    83.22

# %% [markdown]
# ### Handling missing data
#
# Documentation:
# * [`Series.isna`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.isna.html)
# * [`fillna`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html)
# * [`dropna`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)
#
# We used the assign values method to fill in the Music effects fields that were empty, but we can instead use `fillna` to do the same.

# %%
# re-import dataset to undo any changes made
url = 'https://raw.githubusercontent.com/CommunityRADvocate/ida2404-capstone/main/mxmh_survey_results.csv'

df = pd.read_csv(url)

# %%
# find rows with missing values in specified column
df[df['Music effects'].isna()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, Exploratory, Foreign languages, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects, Permissions]
# Index: []
#
# [0 rows x 33 columns]

# %%
df['Music effects'].fillna('No effect', inplace=True)

# %%
# check to make sure we filled the empty values
df[df['Music effects'].isna()]

# %% [markdown]
# There will be times when missing values can't easily be filled, and will not be useful in our analysis. For those instances, we can drop rows with missing data using `dropna()`

# %%
# find rows with missing 'Age'
df[df['Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, Exploratory, Foreign languages, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects, Permissions]
# Index: []
#
# [0 rows x 33 columns]

# %%
df.dropna(subset=['Age'], inplace=True)

# %% [markdown]
# ### Manipulating Text
#
# [Handling strings](https://pandas.pydata.org/pandas-docs/stable/api.html#string-handling)

# %%
from IPython.display import display, Markdown

def render(md):
    return display(Markdown(md))

def make_chaos(df, sample_size, columns, fn):
    # Keep chaos the same randomly
    some = df.sample(sample_size, random_state=sample_size)
    for col in columns:
        some[col] = some[col].apply(fn)
    # Update the original DataFrame
    df.update(some)

# %%
pd.options.display.max_rows = 10
make_chaos(transactions, 42, ['sender'], lambda val: '$' + val)
make_chaos(transactions, 88, ['receiver'], lambda val: val.upper())

# %%
transactions[transactions.sender.str.startswith('$')]
# Out:
# Empty DataFrame
# Columns: [sender, receiver, amount, sent_date]
# Index: []

# %%
# replace '$' with an empty string
transactions.sender = transactions.sender.str.replace('$', '')

# %% [markdown]
# #### Changing Case
#
# Sometimes your data comes with mismatched letter casing within a column, which may cause unexpected results in your analysis.

# %%
# identify rows where 'receiver' column values are uppercase
transactions[transactions.receiver.str.isupper()]
# Out:
# Empty DataFrame
# Columns: [sender, receiver, amount, sent_date]
# Index: []

# %%
# update receiver column of those rows to be lowercase
transactions.loc[transactions.receiver.str.isupper(), 'receiver'] = transactions.receiver.str.lower()

# %% [markdown]
# Here's an example of how you might want to use string methods to update column names in our survey dataset

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('[', '').str.replace(']', '').str.lower().str.replace('frequency', 'fr')
df.columns
# Out:
# Index(['timestamp', 'age', 'primary_streaming_service', 'hours_per_day',
#        'while_working', 'instrumentalist', 'composer', 'fav_genre',
#        'exploratory', 'foreign_languages', 'bpm', 'fr_classical', 'fr_country',
#        'fr_edm', 'fr_folk', 'fr_gospel', 'fr_hip_hop', 'fr_jazz', 'fr_k_pop',
#        'fr_latin', 'fr_lofi', 'fr_metal', 'fr_pop', 'fr_r&b', 'fr_rap',
#        'fr_rock', 'fr_video_game_music', 'anxiety', 'depression', 'insomnia',
#        'ocd', 'music_effects', 'permissions'],
#       dtype='object')

# %% [markdown]
# What's the benefit of formatting your columns in this way?

# %% [markdown]
# ## Grouping
#
# DataFrame.groupby() [Documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)
#
# [API](https://pandas.pydata.org/docs/reference/groupby.html)

# %%
streaming_groups = df.groupby('primary_streaming_service')
type(streaming_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# returns Series of total rows in each group
streaming_groups.age.size()
# Out:
# primary_streaming_service
# Apple Music                           51
# I do not use a streaming service.     71
# Other streaming service               50
# Pandora                               11
# Spotify                              457
# YouTube Music                         94
# Name: age, dtype: int64

# %%
# count how many non missing data points in each column per group
streaming_groups.count()
# Out:
#                                    timestamp  age  hours_per_day  \
# primary_streaming_service
# Apple Music                               51   51             51
# I do not use a streaming service.         71   71             71
# Other streaming service                   50   50             50
# Pandora                                   11   11             11
# Spotify                                  457  457            457
# YouTube Music                             94   94             94
#
#                                    while_working  instrumentalist  composer  \
# primary_streaming_service
# Apple Music                                   51               51        51
# I do not use a streaming service.             70               71        71
# Other streaming service                       50               50        50
# Pandora                                       11               11        11
# Spotify                                      455              455       456
# YouTube Music                                 94               92        94
#
#                                    fav_genre  exploratory  foreign_languages  \
# primary_streaming_service
# Apple Music                               51           51                 51
# I do not use a streaming service.         71           71                 71
# Other streaming service                   50           50                 50
# Pandora                                   11           11                 11
# Spotify                                  457          457                454
# YouTube Music                             94           94                 93
#
#                                    bpm  ...  fr_r&b  fr_rap  fr_rock  \
# primary_streaming_service               ...
# Apple Music                         43  ...      51      51       51
# I do not use a streaming service.   56  ...      71      71       71
# Other streaming service             41  ...      50      50       50
# Pandora                             10  ...      11      11       11
# Spotify                            402  ...     457     457      457
# YouTube Music                       76  ...      94      94       94
#
#                                    fr_video_game_music  anxiety  depression  \
# primary_streaming_service
# Apple Music                                         51       51          51
# I do not use a streaming service.                   71       71          71
# Other streaming service                             50       50          50
# Pandora                                             11       11          11
# Spotify                                            457      457         457
# YouTube Music                                       94       94          94
#
#                                    insomnia  ocd  music_effects  permissions
# primary_streaming_service
# Apple Music                              51   51             51           51
# I do not use a streaming service.        71   71             71           71
# Other streaming service                  50   50             50           50
# Pandora                                  11   11             11           11
# Spotify                                 457  457            457          457
# YouTube Music                            94   94             94           94
#
# [6 rows x 32 columns]
# Warning: Total number of columns (32) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# GroupBy provides aggregate functions that are handy for quick calculations of numeric columns

# %%
streaming_groups.sum()

# %%
streaming_groups.mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-382db6305532> in <cell line: 1>()
# ----> 1 streaming_groups.mean(numeric_only=True)
#
# NameError: name 'streaming_groups' is not defined
